# %%
import pandas as pd
import opendatasets as od

# %%
# od.download("https://www.kaggle.com/competitions/spaceship-titanic")

# %%
raw_data=pd.read_csv('spaceship-titanic/train.csv')
# raw_data=raw_data[~raw_data['Cabin'].isnull()]

# %%
ytrain=raw_data['Transported']

# %%
def clean_dt(raw_data):
    return (raw_data
    .drop(columns=['Name','PassengerId','Destination','HomePlanet','VIP','Age','Cabin'])
    .assign(
        RoomService=raw_data.RoomService.fillna(0).replace('nan',0),
        CryoSleep=raw_data.CryoSleep.fillna(False),
        # VIP=raw_data.VIP.fillna(False).replace('nan',0),
        FoodCourt=raw_data.FoodCourt.fillna(0).replace('nan',0),
        ShoppingMall=raw_data.ShoppingMall.fillna(0).replace('nan',0),
        Spa=raw_data.Spa.fillna(0).replace('nan',0),
        VRDeck=raw_data.VRDeck.fillna(0).replace('nan',0),
        # Cabin=raw_data.Cabin.str.split('/',expand=True)[2]=='S',
        # Age=raw_data.Age.fillna(raw_data.Age.median())
        )
     
    )

# %%
 # encoding boolean labels
from sklearn import preprocessing

def transform_step(raw_data):
    label_encoder=preprocessing.LabelEncoder()
    raw_data.CryoSleep=label_encoder.fit_transform(raw_data.CryoSleep).astype(int)
    # raw_data.Cabin=label_encoder.fit_transform(raw_data.Cabin).astype(int)
    # raw_data.VIP=label_encoder.fit_transform(raw_data.VIP)
    # raw_data=pd.get_dummies(raw_data,columns=['Destination','HomePlanet'])
    return raw_data

# %%
res_encoder=preprocessing.LabelEncoder()

ytrain=res_encoder.fit_transform(ytrain)

# %%
  
Xtrain=clean_dt(raw_data)
Xtrain=transform_step(Xtrain)
Xtrain.drop(columns=['Transported'],inplace=True)   

# cabins=Xtrain.Cabin.str.split('/',expand=True),
# cabins

# %%
raw_test=pd.read_csv('spaceship-titanic/test.csv')
# raw_test=raw_test[~raw_test['Cabin'].isnull()]

Xtest=clean_dt(raw_test)
Xtest=transform_step(Xtest)

# %%
# Port=Xtrain.Cabin.str.split('/',expand=True)
# new_cab=new_cab[2]
# S_Cabin= Xtrain.loc[].split()== "S"
# Xtrain=Xtrain[~Xtrain['Cabin'].isnull()]

# %%
Xtrain.dtypes
# Out:
# CryoSleep         int32
# RoomService     float64
# FoodCourt       float64
# ShoppingMall    float64
# Spa             float64
# VRDeck          float64
# dtype: object

# %%
(Xtrain
 .assign(Transported=ytrain==True)
 .corr(method='spearman')
 .style
 .background_gradient(cmap='RdBu',vmax=1,vmin=-1)
 .set_sticky(axis='index')
)
# Out:
# <style type="text/css">
# #T_11bd0 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_11bd0 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_11bd0_row0_col0, #T_11bd0_row1_col1, #T_11bd0_row2_col2, #T_11bd0_row3_col3, #T_11bd0_row4_col4, #T_11bd0_row5_col5, #T_11bd0_row6_col6 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_11bd0_row0_col1, #T_11bd0_row1_col0 {
#   background-color: #e37e64;
#   color: #f1f1f1;
# }
# #T_11bd0_row0_col2, #T_11bd0_row0_col5, #T_11bd0_row2_col0, #T_11bd0_row5_col0 {
#   background-color: #e27b62;
#   color: #f1f1f1;
# }
# #T_11bd0_row0_col3, #T_11bd0_row3_col0 {
#   background-color: #e48066;
#   color: #f1f1f1;
# }
# #T_11bd0_row0_col4, #T_11bd0_row4_col0 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_11bd0_row0_col6, #T_11bd0_row6_col0 {
#   background-color: #7bb6d6;
#   color: #000000;
# }
# #T_11bd0_row1_col2, #T_11bd0_row1_col5, #T_11bd0_row2_col1, #T_11bd0_row2_col3, #T_11bd0_row3_col2, #T_11bd0_row5_col1 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_11bd0_row1_col3, #T_11bd0_row3_col1, #T_11bd0_row4_col5, #T_11bd0_row5_col4 {
#   background-color: #84bcd9;
#   color: #000000;
# }
# #T_11bd0_row1_col4, #T_11bd0_row4_col1 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_11bd0_row1_col6, #T_11bd0_row4_col6, #T_11bd0_row6_col1, #T_11bd0_row6_col4 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_11bd0_row2_col4, #T_11bd0_row4_col2 {
#   background-color: #75b2d4;
#   color: #f1f1f1;
# }
# #T_11bd0_row2_col5, #T_11bd0_row5_col2 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_11bd0_row2_col6, #T_11bd0_row6_col2 {
#   background-color: #fdddcb;
#   color: #000000;
# }
# #T_11bd0_row3_col4, #T_11bd0_row4_col3 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_11bd0_row3_col5, #T_11bd0_row5_col3 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_11bd0_row3_col6, #T_11bd0_row6_col3 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# #T_11bd0_row5_col6, #T_11bd0_row6_col5 {
#   background-color: #f6b394;
#   color: #000000;
# }
# </style>
# <table id="T_11bd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11bd0_level0_col0" class="col_heading level0 col0" >CryoSleep</th>
#       <th id="T_11bd0_level0_col1" class="col_heading level0 col1" >RoomService</th>
#       <th id="T_11bd0_level0_col2" class="col_heading level0 col2" >FoodCourt</th>
#       <th id="T_11bd0_level0_col3" class="col_heading level0 col3" >ShoppingMall</th>
#       <th id="T_11bd0_level0_col4" class="col_heading level0 col4" >Spa</th>
#       <th id="T_11bd0_level0_col5" class="col_heading level0 col5" >VRDeck</th>
#       <th id="T_11bd0_level0_col6" class="col_heading level0 col6" >Transported</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11bd0_level0_row0" class="row_heading level0 row0" >CryoSleep</th>
#       <td id="T_11bd0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_11bd0_row0_col1" class="data row0 col1" >-0.508773</td>
#       <td id="T_11bd0_row0_col2" class="data row0 col2" >-0.522937</td>
#       <td id="T_11bd0_row0_col3" class="data row0 col3" >-0.504369</td>
#       <td id="T_11bd0_row0_col4" class="data row0 col4" >-0.538649</td>
#       <td id="T_11bd0_row0_col5" class="data row0 col5" >-0.517701</td>
#       <td id="T_11bd0_row0_col6" class="data row0 col6" >0.460132</td>
#     </tr>
#     <tr>
#       <th id="T_11bd0_level0_row1" class="row_heading level0 row1" >RoomService</th>
#       <td id="T_11bd0_row1_col0" class="data row1 col0" >-0.508773</td>
#       <td id="T_11bd0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_11bd0_row1_col2" class="data row1 col2" >0.181157</td>
#       <td id="T_11bd0_row1_col3" class="data row1 col3" >0.430106</td>
#       <td id="T_11bd0_row1_col4" class="data row1 col4" >0.239521</td>
#       <td id="T_11bd0_row1_col5" class="data row1 col5" >0.180872</td>
#       <td id="T_11bd0_row1_col6" class="data row1 col6" >-0.363899</td>
#     </tr>
#     <tr>
#       <th id="T_11bd0_level0_row2" class="row_heading level0 row2" >FoodCourt</th>
#       <td id="T_11bd0_row2_col0" class="data row2 col0" >-0.522937</td>
#       <td id="T_11bd0_row2_col1" class="data row2 col1" >0.181157</td>
#       <td id="T_11bd0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_11bd0_row2_col3" class="data row2 col3" >0.185407</td>
#       <td id="T_11bd0_row2_col4" class="data row2 col4" >0.470270</td>
#       <td id="T_11bd0_row2_col5" class="data row2 col5" >0.497026</td>
#       <td id="T_11bd0_row2_col6" class="data row2 col6" >-0.186388</td>
#     </tr>
#     <tr>
#       <th id="T_11bd0_level0_row3" class="row_heading level0 row3" >ShoppingMall</th>
#       <td id="T_11bd0_row3_col0" class="data row3 col0" >-0.504369</td>
#       <td id="T_11bd0_row3_col1" class="data row3 col1" >0.430106</td>
#       <td id="T_11bd0_row3_col2" class="data row3 col2" >0.185407</td>
#       <td id="T_11bd0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_11bd0_row3_col4" class="data row3 col4" >0.253359</td>
#       <td id="T_11bd0_row3_col5" class="data row3 col5" >0.187538</td>
#       <td id="T_11bd0_row3_col6" class="data row3 col6" >-0.227018</td>
#     </tr>
#     <tr>
#       <th id="T_11bd0_level0_row4" class="row_heading level0 row4" >Spa</th>
#       <td id="T_11bd0_row4_col0" class="data row4 col0" >-0.538649</td>
#       <td id="T_11bd0_row4_col1" class="data row4 col1" >0.239521</td>
#       <td id="T_11bd0_row4_col2" class="data row4 col2" >0.470270</td>
#       <td id="T_11bd0_row4_col3" class="data row4 col3" >0.253359</td>
#       <td id="T_11bd0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_11bd0_row4_col5" class="data row4 col5" >0.437234</td>
#       <td id="T_11bd0_row4_col6" class="data row4 col6" >-0.366099</td>
#     </tr>
#     <tr>
#       <th id="T_11bd0_level0_row5" class="row_heading level0 row5" >VRDeck</th>
#       <td id="T_11bd0_row5_col0" class="data row5 col0" >-0.517701</td>
#       <td id="T_11bd0_row5_col1" class="data row5 col1" >0.180872</td>
#       <td id="T_11bd0_row5_col2" class="data row5 col2" >0.497026</td>
#       <td id="T_11bd0_row5_col3" class="data row5 col3" >0.187538</td>
#       <td id="T_11bd0_row5_col4" class="data row5 col4" >0.437234</td>
#       <td id="T_11bd0_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_11bd0_row5_col6" class="data row5 col6" >-0.347008</td>
#     </tr>
#     <tr>
#       <th id="T_11bd0_level0_row6" class="row_heading level0 row6" >Transported</th>
#       <td id="T_11bd0_row6_col0" class="data row6 col0" >0.460132</td>
#       <td id="T_11bd0_row6_col1" class="data row6 col1" >-0.363899</td>
#       <td id="T_11bd0_row6_col2" class="data row6 col2" >-0.186388</td>
#       <td id="T_11bd0_row6_col3" class="data row6 col3" >-0.227018</td>
#       <td id="T_11bd0_row6_col4" class="data row6 col4" >-0.366099</td>
#       <td id="T_11bd0_row6_col5" class="data row6 col5" >-0.347008</td>
#       <td id="T_11bd0_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It seems that the persons who have billed luxury amenities have a negative relationship with being transported. In simple words, the people who have bills are less likely to be transported.

# %%
# prediction
import xgboost as xgb

# %%
# random_for=xgb.XGBClassifier()
model1=xgb.XGBClassifier()


model1.fit(Xtrain,ytrain)
res=model1.predict(Xtest)

# %%
# submission
result=pd.DataFrame({'PassengerId':raw_test.PassengerId,'Transported':res_encoder.inverse_transform(res)})
result.to_csv('submission.csv',index=False)
